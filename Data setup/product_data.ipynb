# %%
import pandas as pd

# %%
data = {
"division":[
"Chocolate","Chocolate","Chocolate","Chocolate","Chocolate",
"Sugar","Sugar","Sugar","Sugar","Other",
"Sugar","Sugar","Other","Other","Other"
],

"product_name":[
"Wonka Bar - Nutty Crunch Surprise",
"Wonka Bar - Fudge Mallows",
"Wonka Bar -Scrumdiddlyumptious",
"Wonka Bar - Milk Chocolate",
"Wonka Bar - Triple Dazzle Caramel",
"Laffy Taffy",
"SweeTARTS",
"Nerds",
"Fun Dip",
"Fizzy Lifting Drinks",
"Everlasting Gobstopper",
"Hair Toffee",
"Lickable Wallpaper",
"Wonka Gum",
"Kazookles"
],

"factory":[
"Lot's O' Nuts",
"Lot's O' Nuts",
"Lot's O' Nuts",
"Wicked Choccy's",
"Wicked Choccy's",
"Sugar Shack",
"Sugar Shack",
"Sugar Shack",
"Sugar Shack",
"Sugar Shack",
"Secret Factory",
"The Other Factory",
"Secret Factory",
"Secret Factory",
"The Other Factory"
]
}

df_map = pd.DataFrame(data)
df_map.to_csv("D:/nassau_profitability_project/data/mapping/product_factory_mapping.csv",index=False)

# %%
coords = {
"factory":[
"Lot's O' Nuts",
"Wicked Choccy's",
"Sugar Shack",
"Secret Factory",
"The Other Factory"
],

"latitude":[
32.881893,
32.076176,
48.11914,
41.446333,
35.1175
],

"longitude":[
-111.768036,
-81.088371,
-96.18115,
-90.565487,
-89.971107
]
}

df_coords = pd.DataFrame(coords)
df_coords.to_csv("D:/nassau_profitability_project/data/mapping/factory_coordinates.csv",index=False)
